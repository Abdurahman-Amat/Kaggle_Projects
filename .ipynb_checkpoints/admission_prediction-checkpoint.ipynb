# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix

# %%
# Read the whole dataset into a Pandas' DataFrame
local_path1 = r'C:/pythonwork/kaggle/data/graduate-admissions/Admission_Predict.csv'
local_path2 = r'C:/pythonwork/kaggle/data/graduate-admissions/Admission_Predict_Ver1.1.csv'
kaggle_path1 = r'../input/graduate-admissions/Admission_Predict.csv'
kaggle_path2 = r'../input/graduate-admissions/Admission_Predict_Ver1.1.csv'


df = pd.read_csv(local_path1)
df2 = pd.read_csv(local_path2)

# %%
df.shape
# Out:
# (400, 9)

# %%
df2.shape
# Out:
# (500, 9)

# %%
df.head(10)
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
# 5           6        330          115                  5  4.5   3.0  9.34
# 6           7        321          109                  3  3.0   4.0  8.20
# 7           8        308          101                  2  3.0   4.0  7.90
# 8           9        302          102                  1  2.0   1.5  8.00
# 9          10        323          108                  3  3.5   3.0  8.60
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# ...

# %%
df2.head(10)
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
# 5           6        330          115                  5  4.5   3.0  9.34
# 6           7        321          109                  3  3.0   4.0  8.20
# 7           8        308          101                  2  3.0   4.0  7.90
# 8           9        302          102                  1  2.0   1.5  8.00
# 9          10        323          108                  3  3.5   3.0  8.60
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# ...

# %% [markdown]
# It seems both of the datasets are exactly the same for the first 400 entries.
# Use **df2 with 500 entries**.

# %% [markdown]
# **At first, quick check the relationships between each features**

# %%
scatter_matrix(df2.iloc[:, 1:], figsize=(15, 12))
plt.show()

# %%
# Correlation
plt.figure(figsize=(15, 10))
sns.heatmap(df2.iloc[:, 1:].corr(), annot = True, cmap='gray', vmin=0, vmax=1)

# %%
filter_count = df2.columns.isin(['GRE Score', 'TOEFL Score', 'CGPA'])
count_df = df2.iloc[:, filter_count]
scatter_matrix(count_df, figsize=(8, 6))
plt.show()

# %% [markdown]
# From above plot one can see the following important point about the features of the dataset.
# 1. There are clear linear relations between the target, Chance of Admit, and independent variables 'GRE Score', 'TOEFL Score' and 'CGPA' and other features also have linear relation although they have discrete values.
# 2. independent variables 'GRE Score', 'TOEFL Score' and 'CGPA' have continous values while 'University rating', 'SOP', 'LOR' and 'Research' have disceret values.
# -----------------
# The next step will be,
# 1. Data preparation
# 2. Directly use at first the mutiple linear regression, where I will try first with those features with continous values..

# %% [markdown]
# ## Prepare the dataset

# %%
df2.isnull().sum()
# Out:
# Serial No.           0
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %%
df2.dtypes
# Out:
# Serial No.             int64
# GRE Score              int64
# TOEFL Score            int64
# University Rating      int64
# SOP                  float64
# LOR                  float64
# CGPA                 float64
# Research               int64
# Chance of Admit      float64
# dtype: object

# %% [markdown]
# All right, there is no missing / nan values.

# %%
df2.columns.values
# Out:
# array(['Serial No.', 'GRE Score', 'TOEFL Score', 'University Rating',
#        'SOP', 'LOR ', 'CGPA', 'Research', 'Chance of Admit '],
#       dtype=object)

# %%
y = np.asanyarray(df2.iloc[:, -1]) # 'Chance of Admit'
X = np.asanyarray(df2.loc[:,['GRE Score', 'TOEFL Score', 'CGPA']]) # continous valued features

# %%
import sklearn
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
# standardize the feature values
X= preprocessing.StandardScaler().fit(X).transform(X)
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.3, random_state=0)
print ('Train set:', X_train.shape,  y_train.shape)
print ('Test set:', X_test.shape,  y_test.shape)
# Out:
# Train set: (350, 3) (350,)
# Test set: (150, 3) (150,)

# %% [markdown]
# ## Multiple Linear Regression

# %%
from sklearn import linear_model
#
# Build the model
lr = linear_model.LinearRegression()
# Train it
lr.fit(X_train, y_train)
# Make the prediction
y_hat = lr.predict(X_test)

# %%
print("Residual sum of squares: %.4f" % np.mean((y_hat - y_test) ** 2))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % lr.score(X_test, y_test))
# Out:
# Residual sum of squares: 0.0041
# Variance score: 0.77

# %%
# Check RMSE and R2_score
from sklearn.metrics import mean_squared_error, r2_score
test_set_rmse = (np.sqrt(mean_squared_error(y_test, y_hat)))
test_set_r2 = r2_score(y_test, y_hat)
#
print(test_set_rmse)
print(test_set_r2)
# Out:
# 0.06408418647998437
# 0.7749091281555818

# %% [markdown]
# ## Multiple Polynomial Regression
